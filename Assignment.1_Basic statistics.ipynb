# %%
# !pip install pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:/Users/durwa/Downloads/sales data.csv")
print(df.head())
# Out:
# ...
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102960
# 2      16100             112700           9.456886     10657.910160
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0     160346.50120
# 1      89323.89704
# 2     102042.08980
# 3     112235.92530
# 4      19927.05377

# %% [markdown]
# Descriptive Analytics for Numerical Columns
# Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
# Steps:
# Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
# Identify numerical columns in the dataset.
# Calculate the mean, median, mode, and standard deviation for these columns.
# Provide a brief interpretation of these statistics.
# solution:
# The numerical columns of the datasets are volume, Avg price, Total sales, Discount Rate, Discount Amount, Net sales values.
# 2. Calculate Basic Statistics:
# Mean: Average value.
# Median: Middle value of the dataset.
# Mode: Most frequent value in the dataset.
# Standard Deviation: Calculate the variance and take the square root.

# %%
# Describe function of python gives the description of the numerical column (like: mean, mode , median,standard deviation etc..)
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
# dtypes gives the data types of column
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
mode=df['Volume'].mode()
mode
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
df['Avg Price'].mode()
# Out:
# 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64

# %%
df['Total Sales Value'].mode()
# Out:
# 0    24300
# Name: Total Sales Value, dtype: int64

# %%
df['Day'].mode()
# Out:
# 0    Thursday
# Name: Day, dtype: object

# %%
df['Brand'].mode()
# Out:
# 0    Jeera
# Name: Brand, dtype: object

# %% [markdown]
# Data Visualization
# Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
# Histograms:
# Plot histograms for each numerical column.
# Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.
# Boxplots:
# Create boxplots for numerical variables to identify outliers and the interquartile range.
# Discuss any findings, such as extreme values or unusual distributions.
# Bar Chart Analysis for Categorical Column:
# Identify categorical columns in the dataset.
# Create bar charts to visualize the frequency or count of each category.
# Analyze the distribution of categories and provide insights.
# solution:

# %%
#histogram
#for numerical column we create histogram.We analyze that in volume,Avg Price,Total Sales Value,Discount Amount,Net salesValue are 
#shows positive skewness and Discount Rate is show negative skewness.
#Positive skewness means that the outliers are present in upper extreme side and negative skewness means the outlier is present in lower extreme side.
df.hist()
plt.tight_layout()

# %%
#Boxplots
#In the above box plaot we can see that in column volume,Avg Price,Total Sales Price, Discount Amount, Net Sales Value the outlier are present
#in the upper extream side(above 75%)
#and in Discount Rate(%) the outlier is present in lower extream side(below 25%)
#We plot the Box plot for or numerical columns. We analysed that in box plot we can see that in column volume, 
#Avg Price, Total Sales Price, Discount Amount, Net Sales Value the outliers are present in the upper extreme
#side (above 75%) and in Discount Rate(%) the outlier is present in lower extreme side(below 25%)
df.boxplot()
# Out:
# <Axes: >

# %%
def outlier(data, col):
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3-q1
    
    lower = q1-(1.5*iqr)
    upper = q3+(1.5*iqr)
    return lower, upper

# %%
outlier(df,'Discount Rate (%)')
# Out:
# (7.740578646249999, 24.33920237625)

# %%
outlier(df,'Net Sales Value')
# Out:
# (-66266.34766937501, 116316.46916962501)

# %%
outlier(df,'Volume')
# Out:
# (-1.5, 10.5)

# %%
outlier(df,'Avg Price')
# Out:
# (-13987.5, 24552.5)

# %%
outlier(df,'Total Sales Value')
# Out:
# (-73050.0, 128950.0)

# %%
outlier(df,'Discount Amount')
# Out:
# (-6823.594880125001, 12600.549610475)

# %%
sns.boxplot(x=df['Volume'])
# Out:
# <Axes: xlabel='Volume'>

# %%
df.boxplot(column='Avg Price')
# Out:
# <Axes: >

# %%
df.boxplot(column='Total Sales Value')
# Out:
# <Axes: >

# %%
df.boxplot(column='Discount Rate (%)')
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['Discount Rate (%)'])
# Out:
# <Axes: xlabel='Discount Rate (%)'>

# %%
df.boxplot(column='Discount Amount')
# Out:
# <Axes: >

# %%
df.boxplot(column='Net Sales Value')
# Out:
# <Axes: >

# %%
#Barplot
plt.figure(figsize=(10,5))
sns.countplot(x='Day',hue='Brand',data=df)
plt.xlabel('days')
plt.ylabel('no of days')
# Out:
# Text(0, 0.5, 'no of days')

# %%
sns.countplot(y = df['Day'])#SKU, City , BU , Brand , Model .
# Out:
# <Axes: xlabel='count', ylabel='Day'>

# %%
sns.countplot(y = df['SKU'])
# Out:
# <Axes: xlabel='count', ylabel='SKU'>

# %%
sns.countplot(y = df['City'])
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %%
sns.countplot(y = df['Model'])
# Out:
# <Axes: xlabel='count', ylabel='Model'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(df['Brand'])
plt.xlabel('brand')
plt.ylabel('no of brand')
# Out:
# Text(0, 0.5, 'no of brand')

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %% [markdown]
# Conversion of Categorical Data into Dummy Variables
# Objective: To transform categorical variables into a format that can be provided to ML algorithms.
# Steps:
# Discuss the need for converting categorical data into dummy variables (one-hot encoding).
# Apply one-hot encoding to the categorical columns, creating binary (0 or 1) columns for each category.
# Display a portion of the transformed dataset.
#
# Solution:
# •	We used one hot encoding method to convert categorical data into numerical data because machine only understand binary (0 or 1)data.
# •	These are the categorical columns of the datasets:
#        Date, City, Day, SKU, BU, Brand ,Model.

# %%
#Encoding using pandas dummy function.
#we used one hot encoding method to convert categorical data into numerical data becouse machine only understand binary (0 or 1)data.
pd.get_dummies(data=df, columns= ['Date','City','Day','SKU','BU','Brand','Model'])
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102960
# 2         7      16100             112700           9.456886     10657.910160
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df=pd.get_dummies(data=df, columns= ['Date','City','Day','SKU','BU','Brand','Model'])

# %%
df
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102960
# 2         7      16100             112700           9.456886     10657.910160
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %% [markdown]
# Standardization of Numerical Variables
# Objective: To scale numerical variables for uniformity, improving the dataset’s suitability for analytical models.
# Steps:
# Explain the concept of standardization (z-score normalization).
# Standardize the numerical columns using the formula: z=x-mu/sigma
# Show before and after comparisons of the data distributions.
#
# Solution:
# •	Z-score is used to calculate probability with the help of normal distribution.
# •	Z-score bring down every single column in same scale. In Z-score convert mean of every single columns into 0  and standard deviation of every single column is converted into 1.
# •	Formula for Z-score is:
#                          z=x-mu/sigma
# •	It gives the equal importance to every columns.
# •	Z-score used to calculate the probability with the help of normal distribution

# %%
#Z-score is used to calculate probability with the help of normal distribution
#Z-score bring down every single column in same scale. In Z-score mean of every single column is converted into 0.
# and standard deviation of every single column is converted into 1
from sklearn.preprocessing import StandardScaler

# %%
#Standardization
sc = StandardScaler()

# %%
df.columns
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value', 'Date_01-04-2021',
#        'Date_02-04-2021', 'Date_03-04-2021', 'Date_04-04-2021',
#        ...
#        'Model_Vedic Cream', 'Model_Vedic Oil', 'Model_Vedic Shampoo',
#        'Model_W-Casuals', 'Model_W-Inners', 'Model_W-Lounge',
#        'Model_W-Western', 'Model_YM-98 ', 'Model_YM-99', 'Model_YM-99 Plus'],
#       dtype='object', length=101)

# %%
#before comparing of the data distribution
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
df.head(2)
sc.fit_transform(df)
x = sc.fit_transform(df)
x
# Out:
# array([[ 2.35002911,  0.091173  ,  2.92572115, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 1.16712855, -0.01957016,  1.33099521, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 0.45738822,  0.31265934,  1.56277525, ..., -0.18569534,
#          5.38516481, -0.18569534],
#        ...,
#        [-0.72551234, -0.49022863, -0.60644824, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.48893223, -0.47361715, -0.55692259, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.96209245, -0.40717125, -0.60842926, ..., -0.18569534,
#         -0.18569534, -0.18569534]])

# %%
df.dtypes
# Out:
# Volume                 int64
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
#                       ...
# Model_W-Lounge          bool
# Model_W-Western         bool
# Model_YM-98             bool
# Model_YM-99             bool
# Model_YM-99 Plus        bool
# Length: 101, dtype: object

# %%
df
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102960
# 2         7      16100             112700           9.456886     10657.910160
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
df
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102960
# 2         7      16100             112700           9.456886     10657.910160
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
df.columns
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value', 'Date_01-04-2021',
#        'Date_02-04-2021', 'Date_03-04-2021', 'Date_04-04-2021',
#        ...
#        'Model_Vedic Cream', 'Model_Vedic Oil', 'Model_Vedic Shampoo',
#        'Model_W-Casuals', 'Model_W-Inners', 'Model_W-Lounge',
#        'Model_W-Western', 'Model_YM-98 ', 'Model_YM-99', 'Model_YM-99 Plus'],
#       dtype='object', length=101)

# %%
pd.DataFrame(x,columns =df.columns)
scaled_data = pd.DataFrame(x, columns=df.columns)
scaled_data
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value  Date_01-04-2021  Date_02-04-2021  \
# 0           3.952816         2.804756         3.741657        -0.267261
# ...

# %%
#after comparing the data distribution
scaled_data.describe()
# Out:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   6.118562e-17  3.157968e-17       1.578984e-17       4.855375e-16
# std    1.001113e+00  1.001113e+00       1.001113e+00       1.001113e+00
# min   -9.620925e-01 -5.627654e-01      -6.619170e-01      -2.406935e+00
# 25%   -4.889322e-01 -5.530754e-01      -6.163534e-01      -2.823066e-01
# 50%   -2.523521e-01 -4.985344e-01      -5.569226e-01       3.374180e-01
# 75%    2.208081e-01 -1.957016e-02       3.840648e-01       7.019781e-01
# max    6.135311e+00  2.749009e+00       3.220894e+00       1.147360e+00
#
#        Discount Amount  Net Sales Value  Date_01-04-2021  Date_02-04-2021  \
# count     4.500000e+02     4.500000e+02     4.500000e+02     4.500000e+02
# mean      5.526444e-17    -7.105427e-17     1.578984e-16     1.263187e-16
# std       1.001113e+00     1.001113e+00     1.001113e+00     1.001113e+00
# ...

# %%
df.nunique()
# Out:
# Volume                22
# Avg Price             25
# Total Sales Value    135
# Discount Rate (%)    450
# Discount Amount      450
#                     ...
# Model_W-Lounge         2
# Model_W-Western        2
# Model_YM-98            2
# Model_YM-99            2
# Model_YM-99 Plus       2
# Length: 101, dtype: int64
